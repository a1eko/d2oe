# %%
import os

network_path = os.path.join("networks", "d2oe7")
config_file = os.path.join("config", "network-d2oe7.json")

# %% [markdown]
# ## Create the mesh for the neurons

# %%
n_total = 10000
mesh_file = f"config/mesh/mesh-{n_total}.obj"
if not os.path.isfile(mesh_file):
    from snudda.place.create_cube_mesh import create_cube_mesh
    density = 80500
    side_len = (n_total/density)**(1/3)*1e-3
    create_cube_mesh(file_name=mesh_file, centre_point=(0,0,0), side_len=side_len)
    print(f"Created {mesh_file}")
else:
    print(f"Mesh file already exists")
# Out:
# Mesh file already exists

# %% [markdown]
# ## Generate network

# %%
from snudda import Snudda

snd = Snudda(network_path)
snd.import_config(network_config_file=config_file, overwrite=True)
# Out:
# Loading config/network-d2oe7.json
# Loading config/striatum.json
# Loading config/neurons/dspn.json
# Loading config/neurons/ispn.json
# Loading config/neurons/fs.json
# Loading config/neurons/lts.json
# Loading config/striatum-connectivity.json
# Creating directory networks/d2oe7
# Setting network_path = '/home/hjorth/HBP/d2oe/2024Q3/snudda/networks/d2oe7'
# Writing to file networks/d2oe7/network-config.json

# %%
snd.create_network()
# Out:
# Placing neurons
# Network path: networks/d2oe7
# Creating missing directory networks/d2oe7/log
# Created directory networks/d2oe7/log
# Reading SNUDDA_DATA=/home/hjorth/HBP/d2oe/2024Q3/morphology/d2oe7 from networks/d2oe7/network-config.json
# Generating 119144 points for config/mesh/mesh-10000.obj
# Filtering, keeping inside points: 18274 / 22414
# neuron_name = 'dSPN_0', num = 134, neuron_path = '$SNUDDA_DATA/dspn/0/'
# neuron_name = 'dSPN_1', num = 134, neuron_path = '$SNUDDA_DATA/dspn/1/'
# neuron_name = 'dSPN_2', num = 131, neuron_path = '$SNUDDA_DATA/dspn/2/'
# neuron_name = 'dSPN_3', num = 133, neuron_path = '$SNUDDA_DATA/dspn/3/'
# neuron_name = 'dSPN_4', num = 133, neuron_path = '$SNUDDA_DATA/dspn/4/'
# neuron_name = 'dSPN_5', num = 133, neuron_path = '$SNUDDA_DATA/dspn/5/'
# neuron_name = 'dSPN_6', num = 131, neuron_path = '$SNUDDA_DATA/dspn/6/'
# neuron_name = 'dSPN_7', num = 131, neuron_path = '$SNUDDA_DATA/dspn/7/'
# neuron_name = 'dSPN_8', num = 131, neuron_path = '$SNUDDA_DATA/dspn/8/'
# neuron_name = 'dSPN_9', num = 132, neuron_path = '$SNUDDA_DATA/dspn/9/'
# neuron_name = 'dSPN_10', num = 132, neuron_path = '$SNUDDA_DATA/dspn/10/'
# neuron_name = 'dSPN_11', num = 132, neuron_path = '$SNUDDA_DATA/dspn/11/'
# neuron_name = 'dSPN_12', num = 131, neuron_path = '$SNUDDA_DATA/dspn/12/'
# neuron_name = 'dSPN_13', num = 131, neuron_path = '$SNUDDA_DATA/dspn/13/'
# neuron_name = 'dSPN_14', num = 132, neuron_path = '$SNUDDA_DATA/dspn/14/'
# neuron_name = 'dSPN_15', num = 132, neuron_path = '$SNUDDA_DATA/dspn/15/'
# neuron_name = 'dSPN_16', num = 131, neuron_path = '$SNUDDA_DATA/dspn/16/'
# neuron_name = 'dSPN_17', num = 133, neuron_path = '$SNUDDA_DATA/dspn/17/'
# neuron_name = 'dSPN_18', num = 134, neuron_path = '$SNUDDA_DATA/dspn/18/'
# neuron_name = 'dSPN_19', num = 132, neuron_path = '$SNUDDA_DATA/dspn/19/'
# neuron_name = 'dSPN_20', num = 131, neuron_path = '$SNUDDA_DATA/dspn/20/'
# neuron_name = 'dSPN_21', num = 132, neuron_path = '$SNUDDA_DATA/dspn/21/'
# neuron_name = 'dSPN_22', num = 132, neuron_path = '$SNUDDA_DATA/dspn/22/'
# neuron_name = 'dSPN_23', num = 131, neuron_path = '$SNUDDA_DATA/dspn/23/'
# neuron_name = 'dSPN_24', num = 131, neuron_path = '$SNUDDA_DATA/dspn/24/'
# neuron_name = 'dSPN_25', num = 131, neuron_path = '$SNUDDA_DATA/dspn/25/'
# neuron_name = 'dSPN_26', num = 132, neuron_path = '$SNUDDA_DATA/dspn/26/'
# neuron_name = 'dSPN_27', num = 132, neuron_path = '$SNUDDA_DATA/dspn/27/'
# neuron_name = 'dSPN_28', num = 132, neuron_path = '$SNUDDA_DATA/dspn/28/'
# neuron_name = 'dSPN_29', num = 133, neuron_path = '$SNUDDA_DATA/dspn/29/'
# neuron_name = 'dSPN_30', num = 131, neuron_path = '$SNUDDA_DATA/dspn/30/'
# neuron_name = 'dSPN_31', num = 132, neuron_path = '$SNUDDA_DATA/dspn/31/'
# neuron_name = 'dSPN_32', num = 132, neuron_path = '$SNUDDA_DATA/dspn/32/'
# neuron_name = 'dSPN_33', num = 132, neuron_path = '$SNUDDA_DATA/dspn/33/'
# neuron_name = 'dSPN_34', num = 132, neuron_path = '$SNUDDA_DATA/dspn/34/'
# neuron_name = 'dSPN_35', num = 131, neuron_path = '$SNUDDA_DATA/dspn/35/'
# neuron_name = 'iSPN_0', num = 131, neuron_path = '$SNUDDA_DATA/ispn/0/'
# neuron_name = 'iSPN_1', num = 131, neuron_path = '$SNUDDA_DATA/ispn/1/'
# neuron_name = 'iSPN_2', num = 133, neuron_path = '$SNUDDA_DATA/ispn/2/'
# neuron_name = 'iSPN_3', num = 132, neuron_path = '$SNUDDA_DATA/ispn/3/'
# neuron_name = 'iSPN_4', num = 132, neuron_path = '$SNUDDA_DATA/ispn/4/'
# neuron_name = 'iSPN_5', num = 131, neuron_path = '$SNUDDA_DATA/ispn/5/'
# neuron_name = 'iSPN_6', num = 133, neuron_path = '$SNUDDA_DATA/ispn/6/'
# neuron_name = 'iSPN_7', num = 133, neuron_path = '$SNUDDA_DATA/ispn/7/'
# neuron_name = 'iSPN_8', num = 132, neuron_path = '$SNUDDA_DATA/ispn/8/'
# neuron_name = 'iSPN_9', num = 131, neuron_path = '$SNUDDA_DATA/ispn/9/'
# neuron_name = 'iSPN_10', num = 131, neuron_path = '$SNUDDA_DATA/ispn/10/'
# neuron_name = 'iSPN_11', num = 134, neuron_path = '$SNUDDA_DATA/ispn/11/'
# neuron_name = 'iSPN_13', num = 131, neuron_path = '$SNUDDA_DATA/ispn/13/'
# neuron_name = 'iSPN_12', num = 133, neuron_path = '$SNUDDA_DATA/ispn/12/'
# neuron_name = 'iSPN_14', num = 131, neuron_path = '$SNUDDA_DATA/ispn/14/'
# neuron_name = 'iSPN_15', num = 132, neuron_path = '$SNUDDA_DATA/ispn/15/'
# neuron_name = 'iSPN_16', num = 132, neuron_path = '$SNUDDA_DATA/ispn/16/'
# neuron_name = 'iSPN_17', num = 132, neuron_path = '$SNUDDA_DATA/ispn/17/'
# neuron_name = 'iSPN_18', num = 131, neuron_path = '$SNUDDA_DATA/ispn/18/'
# neuron_name = 'iSPN_19', num = 131, neuron_path = '$SNUDDA_DATA/ispn/19/'
# neuron_name = 'iSPN_20', num = 132, neuron_path = '$SNUDDA_DATA/ispn/20/'
# neuron_name = 'iSPN_21', num = 134, neuron_path = '$SNUDDA_DATA/ispn/21/'
# neuron_name = 'iSPN_22', num = 132, neuron_path = '$SNUDDA_DATA/ispn/22/'
# neuron_name = 'iSPN_23', num = 131, neuron_path = '$SNUDDA_DATA/ispn/23/'
# neuron_name = 'iSPN_24', num = 132, neuron_path = '$SNUDDA_DATA/ispn/24/'
# neuron_name = 'iSPN_25', num = 132, neuron_path = '$SNUDDA_DATA/ispn/25/'
# neuron_name = 'iSPN_26', num = 132, neuron_path = '$SNUDDA_DATA/ispn/26/'
# neuron_name = 'iSPN_27', num = 132, neuron_path = '$SNUDDA_DATA/ispn/27/'
# neuron_name = 'iSPN_28', num = 131, neuron_path = '$SNUDDA_DATA/ispn/28/'
# neuron_name = 'iSPN_29', num = 131, neuron_path = '$SNUDDA_DATA/ispn/29/'
# neuron_name = 'iSPN_30', num = 131, neuron_path = '$SNUDDA_DATA/ispn/30/'
# neuron_name = 'iSPN_31', num = 132, neuron_path = '$SNUDDA_DATA/ispn/31/'
# neuron_name = 'iSPN_32', num = 131, neuron_path = '$SNUDDA_DATA/ispn/32/'
# neuron_name = 'iSPN_33', num = 133, neuron_path = '$SNUDDA_DATA/ispn/33/'
# neuron_name = 'iSPN_34', num = 133, neuron_path = '$SNUDDA_DATA/ispn/34/'
# neuron_name = 'iSPN_35', num = 134, neuron_path = '$SNUDDA_DATA/ispn/35/'
# neuron_name = 'FS_0', num = 32, neuron_path = '$SNUDDA_DATA/fs/0/'
# neuron_name = 'FS_1', num = 32, neuron_path = '$SNUDDA_DATA/fs/1/'
# neuron_name = 'FS_2', num = 34, neuron_path = '$SNUDDA_DATA/fs/2/'
# neuron_name = 'FS_3', num = 32, neuron_path = '$SNUDDA_DATA/fs/3/'
# neuron_name = 'LTS_0', num = 7, neuron_path = '$SNUDDA_DATA/lts/0/'
# neuron_name = 'LTS_1', num = 7, neuron_path = '$SNUDDA_DATA/lts/1/'
# neuron_name = 'LTS_2', num = 8, neuron_path = '$SNUDDA_DATA/lts/2/'
# neuron_name = 'LTS_3', num = 7, neuron_path = '$SNUDDA_DATA/lts/3/'
# neuron_name = 'LTS_4', num = 8, neuron_path = '$SNUDDA_DATA/lts/4/'
# neuron_name = 'LTS_5', num = 9, neuron_path = '$SNUDDA_DATA/lts/5/'
# neuron_name = 'LTS_6', num = 8, neuron_path = '$SNUDDA_DATA/lts/6/'
# neuron_name = 'LTS_7', num = 8, neuron_path = '$SNUDDA_DATA/lts/7/'
# Worker synapses: 87038107/87038107 (heap size: 0)
# Read 87038107 out of total 87038107 synapses
# Read 2864 out of total 2864 gap_junctions
# stop_parallel disabled, to keep pool running.
#
# Execution time: 2077.0s

# %% [markdown]
# ## Analyse connectivity

# %%
from snudda.analyse.analyse_striatum import SnuddaAnalyseStriatum

nas = SnuddaAnalyseStriatum(network_path, volume_type="cube")

y_max_H = None  # 0.5
dist3D = True

nas.plot_connection_probability("dSPN", "iSPN",
                                dist_3d=dist3D,
                                exp_max_dist=[50e-6, 100e-6],
                                exp_data=[3 / 47.0, 3 / 66.0],
                                exp_data_detailed=[(3, 47), (3, 66)],
                                y_max=y_max_H)

nas.plot_connection_probability("dSPN", "dSPN",
                                dist_3d=dist3D,
                                exp_max_dist=[50e-6, 100e-6],
                                exp_data=[5 / 19.0, 3 / 43.0],
                                exp_data_detailed=[(5, 19), (3, 43)],
                                y_max=y_max_H)

nas.plot_connection_probability("iSPN", "dSPN",
                                dist_3d=dist3D,
                                exp_max_dist=[50e-6, 100e-6],
                                exp_data=[13 / 47.0, 10 / 80.0],
                                exp_data_detailed=[(13, 47), (10, 80)],
                                y_max=y_max_H)

nas.plot_connection_probability("iSPN", "iSPN",
                                dist_3d=dist3D,
                                exp_max_dist=[50e-6, 100e-6],
                                exp_data=[14 / 39.0, 7 / 31.0],
                                exp_data_detailed=[(14, 39), (7, 31)],
                                y_max=y_max_H)

nas.plot_connection_probability("FS", "iSPN",
                                dist_3d=dist3D,
                                exp_max_dist=[100e-6, 150e-6, 250e-6],
                                exp_data=[6 / 9.0, 21 / 54.0, 27 / 77.0],
                                exp_data_detailed=[(6, 9), (21, 54), (27, 77)],
                                y_max=None)

nas.plot_connection_probability("FS", "dSPN",
                                dist_3d=dist3D,
                                exp_max_dist=[100e-6, 150e-6, 250e-6],
                                exp_data=[8 / 9.0, 29 / 48.0, 48 / 90.0],
                                exp_data_detailed=[(8, 9), (29, 48), (48, 90)],
                                y_max=None)

nas.plot_connection_probability("FS", "FS",
                                dist_3d=dist3D,
                                exp_max_dist=[250e-6],
                                exp_data=[7 / 12.0],
                                exp_data_detailed=[(7, 12)])

nas.plot_connection_probability("FS", "FS",
                                dist_3d=dist3D,
                                connection_type="gapjunctions",
                                exp_max_dist=[200e-6, 250e-6, 250e-6],
                                exp_data=[6/78.0, 2 / 6.0, 3 / 7.0],
                                exp_data_detailed=[(6, 78), (2, 6), (3, 7)])

nas.plot_connection_probability("LTS", "dSPN",
                                dist_3d=dist3D,
                                exp_max_dist=[250e-6],
                                exp_data=[2 / 60.0],
                                exp_data_detailed=[(2, 60)],
                                x_max=500)

nas.plot_connection_probability("LTS", "iSPN",
                                dist_3d=dist3D,
                                exp_max_dist=[250e-6],
                                exp_data=[2 / 60.0],
                                exp_data_detailed=[(2, 60)],
                                x_max=500)

nas.plot_connection_probability("FS", "LTS",
                                dist_3d=dist3D,
                                exp_max_dist=[250e-6],
                                exp_data=[2.0 / 12],
                                exp_data_detailed=[(2, 12)])
# Out:
# Loading networks/d2oe7/network-synapses.hdf5
# Assuming volume type: cube [cube or full]
# Only using 20000 neurons of the connection data
# Creating figures directory networks/d2oe7/figures
# Number of neurons: 9700
# Synapse row 0 - 0.0 % time: 0.059019036998506635 seconds
# Synapse row 1000000 - 27.148343435231926 % time: 1.147839417000796 seconds
# Synapse row 1894488 - 51.43221085792566 % time: 2.127193833999627 seconds
# Synapse row 2788977 - 75.71610542896283 % time: 3.0997333909981535 seconds
# Created connection matrix 4.019877432998328 seconds
# GJ row : 0 - 0.0 %  time : 0.003423595000640489 seconds
# Created gap junction connection matrix 0.004873350000707433 seconds
# Creating population dictionary
# Done.
# Taking corner neurons: Keeping 9700/9700
# Calculating synapse distance histogram
# Creating dist histogram
# n_synapses = 3683466, at 0
# n_synapses = 3683466, at 1000000
# n_synapses = 3683466, at 2000000
# n_synapses = 3683466, at 3000000
# Created distance histogram (optimised) in 3.781837662001635 seconds
# Saving cache to networks/d2oe7/network-synapses.hdf5-cache
# Plotting connection probability dSPN to iSPN (synapses)
# Centering in None : Keeping 4750/4750
# Counting connections
# Requested: 10000000.0 calculated [10000021.]
# P(d<5e-05) = 0.042507901696445846
# P(d<0.0001) = 0.03044169434481346
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1439: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/d2oe7/figures/Network-distance-dependent-connection-probability-dSPN-to-iSPN-synapses-3D-dist.png
# Plotting connection probability dSPN to dSPN (synapses)
# Centering in None : Keeping 4750/4750
# Counting connections
# Requested: 10000000.0 calculated [9997963.]
# P(d<5e-05) = 0.18011199509416304
# P(d<0.0001) = 0.11716754232340923
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1439: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/d2oe7/figures/Network-distance-dependent-connection-probability-dSPN-to-dSPN-synapses-3D-dist.png
# Plotting connection probability iSPN to dSPN (synapses)
# Centering in None : Keeping 4750/4750
# Counting connections
# Requested: 10000000.0 calculated [9999992.]
# P(d<5e-05) = 0.18924052670551494
# P(d<0.0001) = 0.12157554982161653
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1439: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/d2oe7/figures/Network-distance-dependent-connection-probability-iSPN-to-dSPN-synapses-3D-dist.png
# Plotting connection probability iSPN to iSPN (synapses)
# Centering in None : Keeping 4750/4750
# Counting connections
# Requested: 10000000.0 calculated [9997916.]
# P(d<5e-05) = 0.27547467844363493
# P(d<0.0001) = 0.20482826583119895
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1439: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/d2oe7/figures/Network-distance-dependent-connection-probability-iSPN-to-iSPN-synapses-3D-dist.png
# Plotting connection probability FS to iSPN (synapses)
# Centering in None : Keeping 4750/4750
# Counting connections
# Requested: 10000000.0 calculated [617500.]
# P(d<0.0001) = 0.444834560928138
# P(d<0.00015) = 0.32541546564179213
# P(d<0.00025) = 0.14590869368023981
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1439: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/d2oe7/figures/Network-distance-dependent-connection-probability-FS-to-iSPN-synapses-3D-dist.png
# Plotting connection probability FS to dSPN (synapses)
# Centering in None : Keeping 4750/4750
# Counting connections
# Requested: 10000000.0 calculated [617500.]
# P(d<0.0001) = 0.6058836909545834
# P(d<0.00015) = 0.45933885477652436
# P(d<0.00025) = 0.21363462147344564
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1439: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/d2oe7/figures/Network-distance-dependent-connection-probability-FS-to-dSPN-synapses-3D-dist.png
# Plotting connection probability FS to FS (synapses)
# Centering in None : Keeping 130/130
# Counting connections
# Requested: 10000000.0 calculated [16770.]
# P(d<0.00025) = 0.1415800415800416
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1439: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/d2oe7/figures/Network-distance-dependent-connection-probability-FS-to-FS-synapses-3D-dist.png
# Plotting connection probability FS to FS (gapjunctions)
# Centering in None : Keeping 130/130
# Counting connections
# Requested: 10000000.0 calculated [16770.]
# P(d<0.0002) = 0.043266301035953685
# P(d<0.00025) = 0.032432432432432434
# P(d<0.00025) = 0.032432432432432434
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1439: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/d2oe7/figures/Network-distance-dependent-connection-probability-FS-to-FS-gapjunctions-3D-dist.png
# Plotting connection probability LTS to dSPN (synapses)
# Centering in None : Keeping 4750/4750
# Counting connections
# Requested: 10000000.0 calculated [332500.]
# P(d<0.00025) = 0.012304171977398862
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1439: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/d2oe7/figures/Network-distance-dependent-connection-probability-LTS-to-dSPN-synapses-3D-dist.png
# Plotting connection probability LTS to iSPN (synapses)
# Centering in None : Keeping 4750/4750
# Counting connections
# Requested: 10000000.0 calculated [332500.]
# P(d<0.00025) = 0.009911872063242382
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1439: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/d2oe7/figures/Network-distance-dependent-connection-probability-LTS-to-iSPN-synapses-3D-dist.png
# Plotting connection probability FS to LTS (synapses)
# Centering in None : Keeping 70/70
# Counting connections
# Requested: 10000000.0 calculated [9100.]
# P(d<0.00025) = 0.037191650853889945
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1439: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/d2oe7/figures/Network-distance-dependent-connection-probability-FS-to-LTS-synapses-3D-dist.png
# ({0.00025: 0.037191650853889945},
#  'networks/d2oe7/figures/Network-distance-dependent-connection-probability-FS-to-LTS-synapses-3D-dist.png')
